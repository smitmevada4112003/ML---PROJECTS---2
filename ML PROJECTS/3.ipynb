# %%
pip install pandas matplotlib scikit-learn fastapi uvicorn
# Out:
# Requirement already satisfied: pandas in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.3.2)
# Requirement already satisfied: matplotlib in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.10.6)
# Requirement already satisfied: scikit-learn in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.8.0)
# Requirement already satisfied: fastapi in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.135.1)
# Requirement already satisfied: uvicorn in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.41.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\SMIT\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\SMIT\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: starlette>=0.46.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fastapi) (0.52.1)
# Requirement already satisfied: pydantic>=2.7.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in C:\Users\SMIT\AppData\Roaming\Python\Python312\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.7.0->fastapi) (2.41.5)
# Requirement already satisfied: six>=1.5 in C:\Users\SMIT\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from starlette>=0.46.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.11)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression #sai kit learn 
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("salary_integer_100.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0                9   85442
# 1               16  137317
# 2               14  124700
# 3                9   87852
# 4               12  110658

# %%
df.columns  # x= 2d y = 1d
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
X=df[['YearsExperience']] #input 2D
Y=df['Salary']
#1
print(X.head())
#print(Y.head()) #input and output  input - single value 
#  Degree  Age
# Out:
#    YearsExperience
# 0                9
# 1               16
# 2               14
# 3                9
# 4               12

# %%
X_train,X_test,Y_train,Y_test=train_test_split(

    X,Y, test_size=0.2, random_state=42
)

# %%
model=LinearRegression() #  modelconstructor  same linear class initalization

# %%
model.fit(X_train,Y_train)    #  input and out put
# Out:
# LinearRegression()

# %%
ypre=model.predict(X_test)

# %%
r2 = r2_score(Y_test, ypre)
print("R2 Score :", r2)
# Out:
# R2 Score : 0.9977904608661514

# %%
#y = mx + c  // 9449(2)+24k= y 
# output = slope (input) + constant 
print(model.coef_[0]) # experience 1 = 9k 
print(model.intercept_) # rapido= 50rs
# Out:
# 6977.438185349638
# 25188.05425700583

# %%
result = model.predict([[6]])


print(result[0])
# Out:
# 67052.68336910366
# c:\Users\SMIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X,Y, color="blue")
plt.plot(X,model.predict(X),color="red")
plt.xlabel("experience")
plt.ylabel("salary")
plt.title("Expe vs salary")
plt.legend()

plt.show()
# Out:
# C:\Users\SMIT\AppData\Local\Temp\ipykernel_22068\114454543.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pickle

pickle.dump(model,open("Salary_model.pkl","wb"))
